# %%
import requests
from PIL import Image
from PIL import ImageFont
import io
import json

# %%
SUBSCRIPTION_KEY = '7382d82ba05b473b9ae5800910b8fdb2'

# %%
assert SUBSCRIPTION_KEY

# %%
face_api_url = 'https://yoshiayu.cognitiveservices.azure.com/face/v1.0/detect'

# %%
img = Image.open('sample01.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x960 at 0x7F7C28059AC0>

# %%
with open('sample01.jpg', 'rb') as f:
    binary_img = f.read()

# %%
#binary_img
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00@Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x01\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x02\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x05\xa0\xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x03\xc0\x00\x00\x00\x00\xff\xe1\t\xachttp://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="XMP Core 6.0.0"> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about="" xmlns:dc="http://purl.org/dc/elements/1.1/"> <dc:subject> <rdf:Bag> <rdf:li>Photo Booth</rdf:li> </rdf:Bag> </dc:subject> </rdf:Description> </rdf:RDF> </x:xmpmeta>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <?xpacket end="w"?>\x00\xff\xed\x00XPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x1f\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x02\x1c\x02\x19\x00\x0bPhoto Booth\x008BIM\x04%\x00\x00\x00\x00\x00\x10qydB\r8\xc8_28\xd6\x94\xce\xc5!\xca\xff\xe2\x10\x08ICC_PROFILE\x00\x01\x01\x00\x00\x0f\xf8appl\x02\x10\x00\x00mntrRGB XYZ \x07\xe6\x00\x02\x00\x12\x00\x12\x00\x1c\x00\x00acspAPPL\x00\x00\x00\x00APPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-appl\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x12desc\x00\x00\x01\\\x00\x00\x00bdscm\x00\x00\x01\xc0\x00\x00\x04\x9ccprt\x00\x00\x06\\\x00\x00\x00#wtpt\x00\x00\x06\x80\x00\x00\x00\x14rXYZ\x00\x00\x06\x94\x00\x00\x00\x14gXYZ\x00\x00\x06\xa8\x00\x00\x00\x14bXYZ\x00\x00\x06\xbc\x00\x00\x00\x14rTRC\x00\x00\x06\xd0\x00\x00\x08\x0caarg\x00\x00\x0e\xdc\x00\x00\x00 vcgt\x00\x00\x0e\xfc\x00\x00\x000ndin\x00\x00\x0f,\x00\x00\x00>chad\x00\x00\x0fl\x00\x00\x00,mmod\x00\x00\x0f\x98\x00\x00\x00(vcgp\x00\x00\x0f\xc0\x00\x00\x008bTRC\x00\x00\x06\xd0\x00\x00\x08\x0cgT ...

# %%
 headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': SUBSCRIPTION_KEY
}

params = {
    'returnFaceId':'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'

}

res =requests.post(face_api_url,params=params,
                       headers=headers,data=binary_img)

# %%
res
# Out:
# <Response [200]>

# %%
result = res.json()
result
# Out:
# [{'faceId': 'f2d062da-87b1-4bb2-b008-f4b9ece3465f',
#   'faceRectangle': {'top': 294, 'left': 381, 'width': 600, 'height': 600},
#   'faceAttributes': {'smile': 0.0,
#    'headPose': {'pitch': -13.1, 'roll': 3.2, 'yaw': -3.2},
#    'gender': 'male',
#    'age': 39.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.959,
#     'sadness': 0.04,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.04},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.72},
#    'noise': {'noiseLevel': 'low', 'value': 0.0},
#    'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.12,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 1.0},
#      {'color': 'brown', 'confidence': 0.85},
#      {'color': 'gray', 'confidence': 0.83},
#      {'color': 'other', 'confidence': 0.33},
#      {'color': 'blond', 'confidence': 0.02},
#      {'color': 'red', 'confidence': 0.01},
#      {'color': 'white', 'confidence': 0.0}]}}}]

# %%
rect = result[0]['faceRectangle']
rect
# Out:
# {'top': 294, 'left': 381, 'width': 600, 'height': 600}

# %%
from PIL import ImageDraw

# %%
draw = ImageDraw.Draw(img)

# %%
#draw.line([(0, 50), (200, 50), (0, 150), (200, 150)], fill='red', width=5)
#img

# %%
rect
# Out:
# {'top': 294, 'left': 381, 'width': 600, 'height': 600}

# %%
draw.rectangle([(rect['left'], rect['top']), (rect['left']+rect['width'], rect['top']+ rect['height'])], fill=None, outline='green', width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x960 at 0x7F7C28059AC0>

# %%
import requests
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import io
import json

assert SUBSCRIPTION_KEY
face_api_url = 'https://yoshiayu.cognitiveservices.azure.com/face/v1.0/detect'

img = Image.open('sample01.jpg')
with io.BytesIO() as output:
    img.save(output, format="JPEG")
    binary_img = output.getvalue()

#with open('sample01.jpg', 'rb') as f:
#    binary_img = f.read()

headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': SUBSCRIPTION_KEY
}

params = {
    'returnFaceId':'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'

}

res =requests.post(face_api_url,params=params,
                       headers=headers,data=binary_img) 
results = res.json()
for result in results:
    rect = result['faceRectangle']

    draw = ImageDraw.Draw(img)
    draw.rectangle([(rect['left'], rect['top']), (rect['left']+rect['width'], rect['top']+ rect['height'])], fill=None, outline='green', width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x960 at 0x7F7C68217D00>

# %%
result
# Out:
# {'faceId': '00627a00-b306-4793-9af6-279ec82579b4',
#  'faceRectangle': {'top': 294, 'left': 381, 'width': 600, 'height': 600},
#  'faceAttributes': {'smile': 0.0,
#   'headPose': {'pitch': -13.1, 'roll': 3.2, 'yaw': -3.2},
#   'gender': 'male',
#   'age': 39.0,
#   'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#   'glasses': 'NoGlasses',
#   'emotion': {'anger': 0.0,
#    'contempt': 0.0,
#    'disgust': 0.0,
#    'fear': 0.0,
#    'happiness': 0.0,
#    'neutral': 0.959,
#    'sadness': 0.04,
#    'surprise': 0.0},
#   'blur': {'blurLevel': 'low', 'value': 0.04},
#   'exposure': {'exposureLevel': 'goodExposure', 'value': 0.72},
#   'noise': {'noiseLevel': 'low', 'value': 0.0},
#   'makeup': {'eyeMakeup': False, 'lipMakeup': False},
#   'accessories': [],
#   'occlusion': {'foreheadOccluded': False,
#    'eyeOccluded': False,
#    'mouthOccluded': False},
#   'hair': {'bald': 0.12,
#    'invisible': False,
#    'hairColor': [{'color': 'black', 'confidence': 1.0},
#     {'color': 'brown', 'confidence': 0.85},
#     {'color': 'gray', 'confidence': 0.83},
#     {'color': 'other', 'confidence': 0.33},
#     {'color': 'blond', 'confidence': 0.02},
#     {'color': 'red', 'confidence': 0.01},
#     {'color': 'white', 'confidence': 0.0}]}}}
